# %%
link='https://en.wikipedia.org/wiki/NIFTY_50'
import pandas as pd
import os
import certifi
os.environ['SSL_CERT_FILE'] = certifi.where()
data=pd.read_html(link)
data
# Out:
# [                                                    0  \
#  0                                                 NaN
#  1   Performance of the NIFTY 50 index between 1990...
#  2                                          Foundation
#  3                                            Operator
#  4                                           Exchanges
#  5                                      Trading symbol
#  6                                        Constituents
#  7                                                Type
#  8                                    Weighting method
#  9                                     Related indices
#  10                                            Website
#
#                                                      1
#  0                                                 NaN
#  1   Performance of the NIFTY 50 index between 1990...
#  2                        22 April 1996 (28 years ago)
#  3                                         NSE Indices
# ...

# %%
df=data[1]

# %%
l1=[]
for i in df['Sector[15]']:
    l1.append(i[-3:])
l1

# %%
l2=[ i[-3:] for i in df['Sector[15]']]
l2

# %%
df['new']=l1
df

# %%
df
# Out:
#                        Company name      Symbol  \
# 0                 Adani Enterprises    ADANIENT
# 1                 Adani Ports & SEZ  ADANIPORTS
# 2                  Apollo Hospitals  APOLLOHOSP
# 3                      Asian Paints  ASIANPAINT
# 4                         Axis Bank    AXISBANK
# 5                        Bajaj Auto  BAJAJ-AUTO
# 6                     Bajaj Finance  BAJFINANCE
# 7                     Bajaj Finserv  BAJAJFINSV
# 8                Bharat Electronics         BEL
# 9                  Bharat Petroleum        BPCL
# 10                    Bharti Airtel  BHARTIARTL
# 11             Britannia Industries   BRITANNIA
# 12                            Cipla       CIPLA
# 13                       Coal India   COALINDIA
# 14         Dr. Reddy's Laboratories     DRREDDY
# 15                    Eicher Motors   EICHERMOT
# 16                Grasim Industries      GRASIM
# 17                          HCLTech     HCLTECH
# ...

# %%
df
l1=[]
for i in df['Date added[16]']:
    if i[-3]=='[':
        l1.append(i[:-3])
    else:
        l1.append(i)
l1
# Out:
# ['30 September 2022',
#  '28 September 2015',
#  '31 March 2022',
#  '27 April 2012',
#  '27 March 2009',
#  '1 October 2010',
#  '29 September 2017',
#  '2 April 2018',
#  '30 September 2024',
#  '28 October 2002',
#  '1 March 2004',
#  '29 March 2019',
#  '7 October 1998',
#  '10 October 2011',
#  '1 October 2010',
#  '1 April 2016',
#  '2 April 2018',
#  '28 October 2002',
#  '22 April 1996',
#  '31 July 2020',
#  '7 October 1998',
#  '22 April 1996',
#  '22 April 1996',
#  '25 January 2002',
#  '1 April 2013',
#  '7 October 1998',
#  '22 April 1996',
#  '28 September 2018',
#  '8 April 2010',
#  '10 December 2004',
#  '18 September 1996',
#  '1 March 2004',
#  '27 September 2019',
#  '24 September 2007',
#  '12 April 2004',
#  '14 March 2008',
#  '22 April 1996',
#  '25 September 2020',
#  '28 March 2024',
#  '22 April 1996',
#  '17 January 2002',
#  '25 February 2005',
#  '31 March 2021',
#  '22 April 1996',
#  '22 April 1996',
#  '28 March 2014',
#  '2 April 2018',
# ...

# %%
l2=[ i[:-3] if i[-3]=='[' else i   for i in df['Date added[16]'] ]
l2
# Out:
# ['30 September 2022',
#  '28 September 2015',
#  '31 March 2022',
#  '27 April 2012',
#  '27 March 2009',
#  '1 October 2010',
#  '29 September 2017',
#  '2 April 2018',
#  '30 September 2024',
#  '28 October 2002',
#  '1 March 2004',
#  '29 March 2019',
#  '7 October 1998',
#  '10 October 2011',
#  '1 October 2010',
#  '1 April 2016',
#  '2 April 2018',
#  '28 October 2002',
#  '22 April 1996',
#  '31 July 2020',
#  '7 October 1998',
#  '22 April 1996',
#  '22 April 1996',
#  '25 January 2002',
#  '1 April 2013',
#  '7 October 1998',
#  '22 April 1996',
#  '28 September 2018',
#  '8 April 2010',
#  '10 December 2004',
#  '18 September 1996',
#  '1 March 2004',
#  '27 September 2019',
#  '24 September 2007',
#  '12 April 2004',
#  '14 March 2008',
#  '22 April 1996',
#  '25 September 2020',
#  '28 March 2024',
#  '22 April 1996',
#  '17 January 2002',
#  '25 February 2005',
#  '31 March 2021',
#  '22 April 1996',
#  '22 April 1996',
#  '28 March 2014',
#  '2 April 2018',
# ...

# %%
df['date']=l2
df
# Out:
#                        Company name      Symbol  \
# 0                 Adani Enterprises    ADANIENT
# 1                 Adani Ports & SEZ  ADANIPORTS
# 2                  Apollo Hospitals  APOLLOHOSP
# 3                      Asian Paints  ASIANPAINT
# 4                         Axis Bank    AXISBANK
# 5                        Bajaj Auto  BAJAJ-AUTO
# 6                     Bajaj Finance  BAJFINANCE
# 7                     Bajaj Finserv  BAJAJFINSV
# 8                Bharat Electronics         BEL
# 9                  Bharat Petroleum        BPCL
# 10                    Bharti Airtel  BHARTIARTL
# 11             Britannia Industries   BRITANNIA
# 12                            Cipla       CIPLA
# 13                       Coal India   COALINDIA
# 14         Dr. Reddy's Laboratories     DRREDDY
# 15                    Eicher Motors   EICHERMOT
# 16                Grasim Industries      GRASIM
# 17                          HCLTech     HCLTECH
# ...

# %%
df['number']=[i for i in range(1,51)]
df
# Out:
#                        Company name      Symbol  \
# 0                 Adani Enterprises    ADANIENT
# 1                 Adani Ports & SEZ  ADANIPORTS
# 2                  Apollo Hospitals  APOLLOHOSP
# 3                      Asian Paints  ASIANPAINT
# 4                         Axis Bank    AXISBANK
# 5                        Bajaj Auto  BAJAJ-AUTO
# 6                     Bajaj Finance  BAJFINANCE
# 7                     Bajaj Finserv  BAJAJFINSV
# 8                Bharat Electronics         BEL
# 9                  Bharat Petroleum        BPCL
# 10                    Bharti Airtel  BHARTIARTL
# 11             Britannia Industries   BRITANNIA
# 12                            Cipla       CIPLA
# 13                       Coal India   COALINDIA
# 14         Dr. Reddy's Laboratories     DRREDDY
# 15                    Eicher Motors   EICHERMOT
# 16                Grasim Industries      GRASIM
# 17                          HCLTech     HCLTECH
# ...

# %%
df['even_odd']=[ 'even' if i%2==0 else 'odd' for i in df['number']]
df
# Out:
#                        Company name      Symbol  \
# 0                 Adani Enterprises    ADANIENT
# 1                 Adani Ports & SEZ  ADANIPORTS
# 2                  Apollo Hospitals  APOLLOHOSP
# 3                      Asian Paints  ASIANPAINT
# 4                         Axis Bank    AXISBANK
# 5                        Bajaj Auto  BAJAJ-AUTO
# 6                     Bajaj Finance  BAJFINANCE
# 7                     Bajaj Finserv  BAJAJFINSV
# 8                Bharat Electronics         BEL
# 9                  Bharat Petroleum        BPCL
# 10                    Bharti Airtel  BHARTIARTL
# 11             Britannia Industries   BRITANNIA
# 12                            Cipla       CIPLA
# 13                       Coal India   COALINDIA
# 14         Dr. Reddy's Laboratories     DRREDDY
# 15                    Eicher Motors   EICHERMOT
# 16                Grasim Industries      GRASIM
# 17                          HCLTech     HCLTECH
# ...
