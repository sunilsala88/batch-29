# %%
import yfinance as yf
import pandas as pd
name='AAPL'
ticker=yf.Ticker(name)

d=ticker.get_news()
print(d)
df=pd.DataFrame(d)
df
# Out:
# [{'uuid': '55e3a6cf-00d2-3829-b7f4-1e121bc06691', 'title': 'Apple Inc. (AAPL): Slower Revenue Growth vs. Ecosystem Durability – What Wins?', 'publisher': 'Insider Monkey', 'link': 'https://finance.yahoo.com/news/apple-inc-aapl-slower-revenue-085209585.html', 'providerPublishTime': 1737795129, 'type': 'STORY', 'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/fTPNobtT0bdcSxj2xXAamw--~B/aD04MTY7dz0xNDU2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/bd47dc2e86b4a3086f845d200d9daf1f', 'width': 1456, 'height': 816, 'tag': 'original'}, {'url': 'https://s.yimg.com/uu/api/res/1.2/nIyTyNRglKMNfFFMGli.7A--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/bd47dc2e86b4a3086f845d200d9daf1f', 'width': 140, 'height': 140, 'tag': '140x140'}]}, 'relatedTickers': ['AAPL']}, {'uuid': 'fba0a8a6-3c25-3673-9901-7d41e65da65a', 'title': 'Billionaire Steven Cohen Sells Apple Stock and Buys a Little-Known AI Stock
# ...
